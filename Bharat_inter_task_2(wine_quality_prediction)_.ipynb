# %%
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv('/content/winequality.csv')
print(df)
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
df.head(12)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0       0.045                 45.0                 170.0   1.0010  3.00
# 1       0.049                 14.0                 132.0   0.9940  3.30
# 2       0.050                 30.0                  97.0   0.9951  3.26
# 3       0.058                 47.0                 186.0   0.9956  3.19
# 4       0.058                 47.0                 186.0   0.9956  3.19
# 5       0.050                 30.0                  97.0   0.9951  3.26
# 6       0.045                 30.0                 136.0   0.9949  3.18
# 7       0.045                 45.0                 170.0   1.0010  3.00
# 8       0.049                 14.0                 132.0   0.9940  3.30
# 9       0.044                 28.0                 129.0   0.9938  3.22
# 10      0.033                 11.0                  63.0   0.9908  2.99
# 11      0.035                 17.0                 109.0   0.9947  3.14
#
#     sulphates  alcohol  quality
# 0        0.45      8.8        6
# 1        0.49      9.5        6
# 2        0.44     10.1        6
# 3        0.40      9.9        6
# 4        0.40      9.9        6
# 5        0.44     10.1        6
# 6        0.47      9.6        6
# 7        0.45      8.8        6
# 8        0.49      9.5        6
# 9        0.45     11.0        6
# 10       0.56     12.0        5
# 11       0.53      9.7        5

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# Filling the missing values

# %%
for col, value in d.items():
    if col !='type':
        df[col] = df[col].fillna(df[col].mean())

# %%
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['type'] = d['type'].map({'white': 1, 'red': 0})

# %%
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      NaN            7.0             0.270         0.36            20.7
# 1      NaN            6.3             0.300         0.34             1.6
# 2      NaN            8.1             0.280         0.40             6.9
# 3      NaN            7.2             0.230         0.32             8.5
# 4      NaN            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6492   NaN            6.2             0.600         0.08             2.0
# 6493   NaN            5.9             0.550         0.10             2.2
# 6494   NaN            6.3             0.510         0.13             2.3
# 6495   NaN            5.9             0.645         0.12             2.0
# 6496   NaN            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0      0.450000      8.8        6
# 1      0.490000      9.5        6
# 2      0.440000     10.1        6
# 3      0.400000      9.9        6
# 4      0.400000      9.9        6
# ...         ...      ...      ...
# 6492   0.580000     10.5        5
# 6493   0.531215     11.2        6
# 6494   0.750000     11.0        6
# 6495   0.710000     10.2        5
# 6496   0.660000     11.0        6
#
# [6497 rows x 13 columns]

# %% [markdown]
# SCATTER PLOT

# %%
import matplotlib.pyplot as plt

# %%
x1=df['type']
y=df['quality']
plt.scatter(x1,y)

# %%
x2=df['fixed acidity']
y=df['quality']
plt.scatter(x2,y)

# %%
x3=df['volatile acidity']
y=df['quality']
plt.scatter(x3,y)

# %%
x4=df['citric acid']
y=df['quality']
plt.scatter(x4,y)

# %%
x5=df['residual sugar']
y=df['quality']
plt.scatter(x5,y)

# %%
x6=df['chlorides']
y=df['quality']
plt.scatter(x6,y)

# %%
x7=df['free sulfur dioxide']
y=df['quality']
plt.scatter(x7,y)

# %%
x8=df['total sulfur dioxide']
y=df['quality']
plt.scatter(x8,y)

# %%
x9=df['density']
y=df['quality']
plt.scatter(x9,y)

# %%
x10=df['pH']
y=df['quality']
plt.scatter(x10,y)

# %%
x11=df['sulphates']
y=df['quality']
plt.scatter(x11,y)

# %%
x12=df['alcohol']
y=df['quality']
plt.scatter(x12,y)

# %%
# value counts of type
df['type'].value_counts()
# Out:
# Series([], Name: type, dtype: int64)

# %% [markdown]
#  CHECKING NULL VALUES

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def heat_map(df):
  plt.figure(figsize=(6,4))
  sns.heatmap(df.isnull())
  return plt.show()

heat_map(df)

# %%
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in df.items():
    if col != 'type':
        sns.boxplot(y=col, data=df, ax=ax[index])
        index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %%
fig, ax = plt.subplots(ncols = 6,nrows=2, figsize=(20,10))
index=0
ax = ax.flatten()

for col, value in df.items():
    if col != 'type':
        sns.distplot(value, ax=ax[index])
        index += 1
plt.tight_layout(pad=0.5, w_pad= 0.7, h_pad=5.0)

# %% [markdown]
# CORRELATIONAL MATRIX

# %%
corr_matrix=d.corr()
print(corr_matrix)
# Out:
#                       type  fixed acidity  volatile acidity  citric acid  \
# type                   NaN            NaN               NaN          NaN
# fixed acidity          NaN       1.000000          0.219918     0.323349
# volatile acidity       NaN       0.219918          1.000000    -0.377759
# citric acid            NaN       0.323349         -0.377759     1.000000
# residual sugar         NaN      -0.112219         -0.196578     0.142451
# chlorides              NaN       0.298282          0.377122     0.039310
# free sulfur dioxide    NaN      -0.283237         -0.353055     0.133426
# total sulfur dioxide   NaN      -0.329409         -0.414706     0.195148
# density                NaN       0.458941          0.271107     0.096307
# pH                     NaN      -0.251683          0.260283    -0.328354
# sulphates              NaN       0.300225          0.225313     0.057564
# alcohol                NaN      -0.095560         -0.038215    -0.010431
# quality                NaN      -0.076967         -0.265838     0.085699
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# type                             NaN        NaN                  NaN
# fixed acidity              -0.112219   0.298282            -0.283237
# volatile acidity           -0.196578   0.377122            -0.353055
# citric acid                 0.142451   0.039310             0.133426
# residual sugar              1.000000  -0.128887             0.403242
# chlorides                  -0.128887   1.000000            -0.194978
# free sulfur dioxide         0.403242  -0.194978             1.000000
# total sulfur dioxide        0.495704  -0.279547             0.720934
# density                     0.552487   0.362580             0.025717
# pH                         -0.266717   0.044754            -0.145116
# sulphates                  -0.185716   0.395073            -0.188471
# alcohol                    -0.359656  -0.256844            -0.179838
# quality                    -0.036819  -0.200818             0.055463
#
#                       total sulfur dioxide   density        pH  sulphates  \
# type                                   NaN       NaN       NaN        NaN
# fixed acidity                    -0.329409  0.458941 -0.251683   0.300225
# volatile acidity                 -0.414706  0.271107  0.260283   0.225313
# citric acid                       0.195148  0.096307 -0.328354   0.057564
# residual sugar                    0.495704  0.552487 -0.266717  -0.185716
# chlorides                        -0.279547  0.362580  0.044754   0.395073
# free sulfur dioxide               0.720934  0.025717 -0.145116  -0.188471
# total sulfur dioxide              1.000000  0.032395 -0.237523  -0.275291
# density                           0.032395  1.000000  0.011913   0.259432
# pH                               -0.237523  0.011913  1.000000   0.191075
# sulphates                        -0.275291  0.259432  0.191075   1.000000
# alcohol                          -0.265740 -0.686745  0.120939  -0.003261
# quality                          -0.041385 -0.305858  0.019356   0.038713
#
#                        alcohol   quality
# type                       NaN       NaN
# fixed acidity        -0.095560 -0.076967
# volatile acidity     -0.038215 -0.265838
# citric acid          -0.010431  0.085699
# residual sugar       -0.359656 -0.036819
# chlorides            -0.256844 -0.200818
# free sulfur dioxide  -0.179838  0.055463
# total sulfur dioxide -0.265740 -0.041385
# density              -0.686745 -0.305858
# pH                    0.120939  0.019356
# sulphates            -0.003261  0.038713
# alcohol               1.000000  0.444319
# quality               0.444319  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(20,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.show()

# %%
sns.distplot(df['free sulfur dioxide'])
# Out:
# <Axes: xlabel='free sulfur dioxide', ylabel='Density'>

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,:-1].values

# %%
x
# Out:
# array([[   nan,  7.   ,  0.27 , ...,  3.   ,  0.45 ,  8.8  ],
#        [   nan,  6.3  ,  0.3  , ...,  3.3  ,  0.49 ,  9.5  ],
#        [   nan,  8.1  ,  0.28 , ...,  3.26 ,  0.44 , 10.1  ],
#        ...,
#        [   nan,  6.3  ,  0.51 , ...,  3.42 ,  0.75 , 11.   ],
#        [   nan,  5.9  ,  0.645, ...,  3.57 ,  0.71 , 10.2  ],
#        [   nan,  6.   ,  0.31 , ...,  3.39 ,  0.66 , 11.   ]])

# %%
# %matplotlib inline
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
X = df.drop(columns=['type', 'quality'])
y = df['quality']

# %%
y.value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
oversample = SMOTE(k_neighbors=4)
# transform the dataset
X, y = oversample.fit_resample(X, y)

# %%
y.value_counts()
# Out:
# 6    2836
# 5    2836
# 7    2836
# 8    2836
# 4    2836
# 3    2836
# 9    2836
# Name: quality, dtype: int64

# %% [markdown]
# Model training

# %%
 #classify function
from sklearn.model_selection import cross_val_score, train_test_split
def classify(model, X, y):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    # train the model
    model.fit(x_train, y_train)
    print("Accuracy:", model.score(x_test, y_test) * 100)

    # cross-validation
    score = cross_val_score(model, X, y, cv=5)
    print("CV Score:", np.mean(score)*100)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
classify(model, X, y)
# Out:
# Accuracy: 50.69731496180213
# CV Score: -973.5928571301363

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
classify(model, X, y)
# Out:
# Accuracy: 87.82994156760024
# CV Score: 82.33934818365137
